# %% [markdown]
# # CMS Blue Button 2.0 Sandbox Query Demo
#
# This notebook demonstrates authenticating and querying the BB2 sandbox.

# %%
from bb2_auth import get_token
from bb2_queries import get_patient, get_eob, get_coverage
from fhir_response_parser import parse_patient, parse_eob_total, parse_coverage
import pandas as pd

# %%
# This will open a browser for OAuth2 authentication
# token = get_token()

# %% [markdown]
# ## Query and Parse Resources

# %%
# patient_raw = get_patient(token)
# eob_list = get_eob(token)
# coverage_list = get_coverage(token)

# patient_data = parse_patient(patient_raw)
# eob_data = parse_eob_total(eob_list)
# coverage_data = parse_coverage(coverage_list)

# print(f"Patient: {patient_data['bene_id']}")
# print(f"Total EOB Amount: {eob_data['total_amount']} {eob_data['currency']}")
# print(f"Coverage Gap Confirmed: {coverage_data['gap_confirmed']}")
