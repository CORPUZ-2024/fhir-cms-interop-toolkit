# %% [markdown]
# # CMS Flat-File to FHIR Gap Analysis
#
# This notebook synthesizes results from the FHIRMapper and BB2 Sandbox validation.

# %%
import sys
import os
sys.path.append('..')
from gap_report_generator import build_gap_table, render_gap_report
import pandas as pd

# %%
df = build_gap_table('mssp_puf')
df

# %%
render_gap_report(df)
