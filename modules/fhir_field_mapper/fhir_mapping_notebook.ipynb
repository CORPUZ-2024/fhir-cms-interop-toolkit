# %% [markdown]
# # FHIR Mapping Library Demo
#
# This notebook demonstrates the `FHIRMapper` library.

# %%
import sys
import os
sys.path.append('..')
from fhir_mapper import FHIRMapper
import pandas as pd

# %%
mapper = FHIRMapper()
results = mapper.map_all('mssp_puf')
df = pd.DataFrame([vars(r) for r in results])
df
